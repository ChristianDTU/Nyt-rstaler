# %%
import re
import os
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import DanishStemmer
nltk.download('stopwords')
nltk.download('punkt_tab', quiet=True)

stemmer = DanishStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Bruger\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Open speech
speech_file = r"Talerne\Margrethe\Margrethe 2004.txt"
with open(speech_file, encoding='utf-8') as speech:
    speech = speech.read()

# Open stopwords_list:
stop_words_file = r"stopwords-dansk.txt"
with open(stop_words_file, encoding='utf-8') as stop_words_list:
    stop_words_list = stop_words_list.read().splitlines()
    

def preprocess_speech(speech,stopwords,stemmer):
    # fjerner puncutation 
    speech = re.sub("[,-:'*.?:;–]"," ",speech)

    # lowercase:
    speech = speech.lower()

    # Tokenize
    tokens = [word for word in word_tokenize(speech)]

    # remove stopwords
    tokens = [word for word in tokens if word not in stopwords]

    # stemme
    tokens = [stemmer.stem(word) for word in tokens]
    return tokens

preprocess_speech(speech,stop_words_list,stemmer)
# Out:
# ['sand',
#  'forbind',
#  'forfærd',
#  'naturkatastrof',
#  'sydøstasi',
#  'uhyg',
#  'kraft',
#  'fejed',
#  'flodbølg',
#  'kyst',
#  'indisk',
#  'ocean',
#  'ført',
#  'død',
#  'ødelæg',
#  'tusind',
#  'ofr',
#  'dansk',
#  'famili',
#  'dag',
#  'føl',
#  'dybt',
#  'berørt',
#  'tank',
#  'øverst',
#  'ikk',
#  'ubekend',
#  'naturkatastrof',
#  'fjern',
#  'egn',
#  'tror',
#  'ram',
#  'glad',
#  'turist',
#  'søg',
#  'varm',
#  'sol',
#  'hav',
#  'blåt',
#  'kyst',
#  'ikk',
#  'tænk',
#  'egn',
#  'tab',
#  'tusind',
#  'mennesk',
#  'tilvær',
#  'slået',
#  'itu',
#  'ikk',
#  'glem',
#  'famili',
#  'land',
#  'oprind',
#  'hårdest',
#  'ramt',
#  'områd',
#  'lev',
#  'dag',
#  'uvis',
#  'gået',
#  'slægtning',
#  'oprind',
#  'hjemegn',
#  'varm',
#  'offervilj',
#  'yder',
#  'eget',
#  'initiativ',
#  'ihærd',
#  'arbejd',
#  'gør',
#  'dansk',
#  'sid',
#  'send',
#  'hjælp',
#  'hårdest',
#  'ramt',
#  'samfund',
#  'lev',
#  'verd',
#  'forandring',
#  'tror',
#  'fremskrid',
#  'forvent',
#  'fremgang',
#  'forfædr',
#  'liv',
#  'foregik',
#  'rol',
#  'tempo',
#  'morgendag',
#  'forudsig',
#  'tilbageblik',
#  'fortid',
#  'virk',
#  'trygt',
#  'oversku',
#  'fremtid',
#  'fuld',
#  '``',
#  "''",
#  '``',
#  'mon',
#  "''",
#  'beregn',
#  'opstil',
#  'prognos',
#  'læg',
#  'plan',
#  'sæt',
#  'mål',
#  'bedr',
#  'mennesk',
#  'triv',
#  'bedr',
#  'par',
#  'generation',
#  'øged',
#  'velstand',
#  'verd',
#  'danmark',
#  'ikk',
#  'hersk',
#  'tvivl',
#  'ikk',
#  'fremskrid',
#  'samfund',
#  'hel',
#  'enkelt',
#  'forhold',
#  'men',
#  'gået',
#  'fremad',
#  'åbn',
#  'udadtil',
#  'verd',
#  'indadtil',
#  'hinand',
#  'ord',
#  'overs',
#  'spænding',
#  'samfund',
#  'hersk',
#  'delt',
#  'mening',
#  'vej',
#  'frem',
#  'åbent',
#  'samfund',
#  'enkelt',
#  'frit',
#  'giv',
#  'udtryk',
#  'tank',
#  'mening',
#  'ubekvem',
#  'forvent',
#  'stå',
#  'uimodsag',
#  'demokratisk',
#  'tradition',
#  'selvfølg',
#  'demokrati',
#  'gror',
#  'ikk',
#  'frem',
#  'kast',
#  'blik',
#  'verd',
#  'fin',
#  'plant',
#  'sagt',
#  'stærk',
#  'kræv',
#  'luft',
#  'lys',
#  'triv',
#  'fordr',
#  'læ',
#  'vantriv',
#  'pas',
#  'vigt',
#  'hinand',
#  'plad',
#  'forskel',
#  'synspunk',
#  'vigt',
#  'stop',
#  'frygt',
#  'truer',
#  'samfundsform',
#  'ønsk',
#  'samfund',
#  'hersk',
#  'åben',
#  'toleranc',
#  'samtid',
#  'stå',
#  'fast',
#  'værdi',
#  'ans',
#  'grundlæg',
#  'fællesskab',
#  'vansk',
#  'balanc',
#  'demokrati',
#  'fortræd',
#  'overreag',
#  'styrk',
#  'ikk',
#  'demokrati',
#  'duk',
#  'lad',
#  'stå',
#  'udfordring',
#  'alvor',
#  'lad',
#  'blik',
#  'vandr',
#  'par',
#  'generation',
#  'tid',
#  'fremskrid',
#  'ikk',
#  'materielt',
#  'hverdag',
#  'hjælpemidl',
#  'trod',
#  'blev',
#  'komplek',
#  'kræv',
#  'ikk',
#  'våg',
#  'svært',
#  'begrib',
#  'foregår',
#  'nemt',
#  'rend',
#  'end',
#  'kørt',
#  'sidespor',
#  'tal',
#  'deltag',
#  'samfund',
#  'udvikling',
#  'mening',
#  'værn',
#  'samfund',
#  'opbyg',
#  'generation',
#  'samfund',
#  'byg',
#  'enkelt',
#  'værd',
#  'plad',
#  'grup',
#  'luk',
#  'end',
#  'begiven',
#  'famili',
#  'kronprin',
#  'frederik',
#  'kronprinses',
#  'mary',
#  'lyk',
#  'glæd',
#  'hinand',
#  'spred',
#  'varmt',
#  'skær',
#  'frem',
#  'strål',
#  'tid',
#  'bryllup',
#  'som',
#  'løb',
#  'året',
#  'mærk',
#  'varm',
#  'medlev',
#  'angår',
#  'famili',
#  'prins',
#  'dej',
#  'begiven',
#  'meg',
#  'opmærksom',
#  'varm',
#  'glæd',
#  'søst',
#  'prinses',
#  'benedik',
#  'dybt',
#  'taknem',
#  'interes',
#  'rund',
#  'fødselsdag',
#  'april',
#  '``',
#  'sor',
#  'glæd',
#  'vandr',
#  'hob',
#  "''",
#  'famili',
#  'undgår',
#  'tung',
#  'tid',
#  'betyd',
#  'famili',
#  'mærk',
#  'sympati',
#  'forstå',
#  'vis',
#  'prin',
#  'joachim',
#  'prinses',
#  'alexandra',
#  'vansk',
#  'tid',
#  'gennemlev',
#  'forbind',
#  'separation',
#  'lev',
#  'glæd',
#  'sorg',
#  'styrk',
#  'mor',
#  'rør',
#  'trygt',
#  'samfund',
#  'dansk',
#  'ulyk',
#  'brat',
#  'slå',
#  'ændr',
#  'vid',
#  'arbejd',
#  'livsopgav',
#  'yde',
#  'hjælp',
#  'tænk',
#  'indsat',
#  'beredskab',
#  'redningstjenest',
#  'politi',
#  'efterår',
#  'voldsom',
#  'eksplosionsbrand',
#  'pluds',
#  'forvandled',
#  'stil',
#  'villakvart',
#  'inferno',
#  'tøved',
#  'ikk',
#  'rysted',
#  'ikk',
#  'hånd',
#  'skønt',
#  'kosted',
#  'liv',
#  'skyld',
#  'tak',
#  'regn',
#  'året',
#  'dag',
#  'naturkatastrof',
#  'voldsom',
#  'ulyk',
#  'lang',
#  'slip',
#  'ikk',
#  'strak',
#  'berørt',
#  'tank',
#  'medføl',
#  'blev',
#  'ramt',
#  'året',
#  'løb',
#  'prøv',
#  'trøst',
#  'opmuntring',
#  'aft',
#  'bring',
#  'forsvar',
#  'nytårshils',
#  'tjenest',
#  'land',
#  'udsend',
#  'arbejd',
#  'oft',
#  'vansk',
#  'forhold',
#  'indsat',
#  'nyd',
#  'anerkend',
#  'respek',
#  'hjem',
#  'dansk',
#  'befind',
#  'aft',
#  'danmark',
#  'valg',
#  'læg',
#  'virk',
#  'fremmed',
#  'udsend',
#  'kort',
#  'tid',
#  'dansk',
#  'dag',
#  'engag',
#  'hjælpearbejd',
#  'sydøstasi',
#  'send',
#  'god',
#  'ønsk',
#  'indsat',
#  'yder',
#  'danmark',
#  'land',
#  'kend',
#  'respek',
#  'regn',
#  'prins',
#  'mul',
#  'att',
#  'træf',
#  'dansk',
#  'sydslesv',
#  'forbind',
#  'slesv',
#  'bys',
#  'jubilæum',
#  'kort',
#  'mød',
#  'dannevirk',
#  'kirk',
#  'gottorp',
#  'slot',
#  'stå',
#  'smukt',
#  'varmt',
#  'mind',
#  'ønsk',
#  'nytår',
#  'som',
#  'fejred',
#  'grønland',
#  'hjemmestyr',
#  'jubilæum',
#  'dej',
#  'oplev',
#  'prins',
#  'deltag',
#  'festlighed',
#  'grønlandsk',
#  'folk',
#  'påtag',
#  'ansvar',
#  'grønland',
#  've',
#  'hjemmestyr',
#  'opnå',
#  'resultat',
#  'rejs',
#  'kronprinspar',
#  'mærk',
#  'udvikling',
#  'grønlandsk',
#  'samfund',
#  'står',
#  'midt',
#  'lev',
#  'engagement',
#  'gæld',
#  'modtag',
#  'naturindtryk',
#  'stå',
#  'uforglem',
#  'mind',
#  'tak',
#  'gaml',
#  'ønsk',
#  'nytår',
#  'grønland',
#  'som',
#  'tur',
#  'att',
#  'nordpå',
#  'kronprinspar',
#  'færø',
#  'rejs',
#  'frem',
#  'glad',
#  'forventning',
#  'mød',
#  'færing',
#  'færøsk',
#  'samfund',
#  'ønsk',
#  'nytår',
#  'h',
#  'c',
#  'anders',
#  'født',
#  'fejr',
#  'herhjem',
#  'sted',
#  'verd',
#  'kend',
#  'elsk',
#  'eventyr',
#  'histori',
#  'tid',
#  'romantisk',
#  'gemyt',
#  'samtid',
#  'mærk',
#  'mod',
#  'mennesk',
#  'forstod',
#  'lod',
#  'begejstr',
#  'tid',
#  'videnskab',
#  'opdag',
#  '``',
#  'tid',
#  'eventyr',
#  'tid',
#  "''",
#  'skrev',
#  'tid',
#  'ikk',
#  '!',
#  'forunder',
#  'tid',
#  'lev',
#  'kortlæg',
#  'træng',
#  'uend',
#  'rum',
#  'udforsk',
#  'galaks',
#  'fjern',
#  'sviml',
#  'find',
#  'stof',
#  'mindst',
#  'stør',
#  'mål',
#  'tank',
#  'lev',
#  'samtid',
#  'verd',
#  'sol',
#  'står',
#  'himl',
#  'stjern',
#  'hvælv',
#  'glæd',
#  'syn',
#  'smag',
#  'æbl',
#  'mærk',
#  'varm',
#  'nær',
#  'hund',
#  'trøst',
#  'blik',
#  'står',
#  'føl',
#  'kærtegn',
#  'hånd',
#  'kend',
#  'mennesk',
#  'tid',
#  'ikk',
#  'stør',
#  'ikk',
#  'ring',
#  'mørkest',
#  'vinterdag',
#  'glæd',
#  'pluds',
#  'træng',
#  'solstrejf',
#  'lirk',
#  'knud',
#  'uløs',
#  'dæmp',
#  'sorg',
#  'ubær',
#  'solstrejf',
#  'mørkest',
#  'dag',
#  'glæd',
#  'tænd',
#  'sår',
#  'læg',
#  'ræk',
#  'hinand',
#  'hånd',
#  'revn',
#  'spræk',
#  'ikk',
#  'afgrund',
#  'tank',
#  'læg',
#  'håb',
#  'fortrøstning',
#  'famili',
#  'ønsk',
#  'gud',
#  'bevar',
#  'danmark']

# %%
# Dansk sentence tokenization
# Eksempel
with open(r"Talerne\Margrethe\Margrethe 1972.txt", encoding='utf-8') as f:
    f = f.read()

nltk.sent_tokenize(f,language="danish")
# Out:
# [' For min familie og for mig selv blev dette år skelsættende ved min fader kong Frederiks sygdom og død.',
#  'Den dybe sorg, der ramte os, følte vi, at hele folket tog del i, og jeg kan ikke begynde denne min første nytårshilsen uden at bringe en tak for al den varme og sympati, som blev prins Henrik og mig, men ikke mindst min moder, dronning Ingrid, til del.',
#  'De hjertelige følelser, som i de tunge dage støttede og løftede os, har jeg siden i årets løb mødt så mange gange, og det har været mig en glæde og inspiration i min gerning som Danmarks dronning.',
#  '1972 vil blive et historisk år på mange måder.',
#  'I Danmarkshistorien vil året blive husket for den betydningsfulde beslutning, som det danske folk traf om Danmarks medlemskab af det udvidede europæiske fællesskab.',
#  'Hermed træder vi ind i et nært samarbejde med de vigtigste vesteuropæiske nationer, vi går ind til det med store forhåbninger, men selvsagt også med en bevidsthed om, at dette vil stille krav til dansk kultur- og samfundsliv.',
#  'Jeg udtrykker et inderligt håb om og en tro på, at det bedste i dansk ånd og kultur vil formå ikke blot at hævde sig, men også bidrage positivt til nationernes samarbejde.',
#  'Dette gælder naturligvis også i en videre forstand de mange områder, hvor Danmark deltager eller står overfor at skulle deltage i internationalt samarbejde.',
#  'Jeg tænker i første række på FN, på den forestående konference om sikkerhed og samarbejde i Europa og på vort samarbejde med de andre nordiske lande, til hvem vi er knyttet med så stærke bånd.',
#  '1972 vil sikkert også komme til at stå som et betydningsfuldt år i verdenshistorien.',
#  'I Europa har vi set væsentlige skridt imod en udsoning af modsætningsforholdet mellem de to Tysklande, der vil sætte sig spor i forholdet også til de andre europæiske lande.',
#  'Medens det endnu kort før jul var en udbredt forventning, at den blodige krig i Vietnam endelig nærmede sig afslutningen, har vi i den seneste tid været vidne til en ny tragisk vending ved en genopblusning af krigshandlingerne.',
#  'Det seneste døgns efterretninger får os til at håbe, at freden endelig må komme til dette ulykkelige land.',
#  'Jeg vil samtidig udtrykke håbet om, at det ny kapitel i forhandlingens og samarbejdets ånd i forholdet mellem de store magter og i det internationale samfund som helhed, der syntes indledt i 1972, vil vise sig at indfri forventningerne, således at det virkelige verdensomspændende samarbejde for menneskehedens fremtid kan få bærekraft.',
#  'Jeg tror, at det er en udbredt følelse i vort land, ligesom i mange af de lande, vi er nært knyttet til, at det moderne industrialiserede samfund går en lang række alvorlige problemer i møde, problemer såvel af social og økonomisk som af menneskelig og ikke mindst miljømæssig karakter.',
#  'Hvis det fri og tolerante velfærdssamfund vi hidtil har kendt, og som har værdi for os, skal kunne fortsætte, er det nødvendigt, at disse problemer finder en løsning.',
#  'Jeg håber, og jeg tror, at vor livsholdning og vore institutioner må vise sig at slå til.',
#  'Vi ønsker alle en verden i fred, ikke blot for os selv, men også for kommende generationer.',
#  'Men dette mål er ikke alene et spørgsmål om at undgå krig og vold.',
#  'Skal freden vindes, er det tillige nødvendigt, at vi ikke begrænser vor horisont til blot at omfatte os selv og vore egne behov, men at vi også tænker på de fattigste dele af verden og på kommende slægters mulighed for at eksistere.',
#  'Det har været min mand og mig en meget stor glæde sammen med vore børn at aflægge en række besøg rundt omkring i landet, og den hjertelige velkomst, der overalt blev os til del, vil vi bevare som et kært og festligt minde.',
#  'Vi håber i de kommende år at kunne fortsætte disse besøg og udstrække dem til Grønland og Færøerne.',
#  'Netop her ved årsskiftet vil jeg gerne sende en særlig hilsen til det grønlandske og det færøske folk, der under indbyrdes forskellige, men altid barske vilkår står midt i en stærk samfundsmæssig og erhvervsmæssig udbygning.',
#  'Jeg er forvisset om, at de fortsat - uden at slippe deres kulturarv - vil have livsmod og kræfter til at løse denne opgave.',
#  'Til alle i forsvaret og politiet retter jeg en tak for veludført gerning i det forløbne år til beskyttelse af vor frihed og fred.',
#  'Min hilsen går også til vore landsmænd syd for grænsen og til alle danske, der rundt omkring i verden - på søen såvel som til lands - har deres daglige gerning.',
#  'Nu er det gamle år næsten forbi, et nyt står for døren.',
#  'Mine tanker går til alle, der er syge, og til alle, der mistet en af de nære.',
#  'Måtte 1973 blive et godt år for vort land.',
#  'Måtte lykke og velsignelse bo i alle danske hjem.',
#  'GUD BEVARE DANMARK']
